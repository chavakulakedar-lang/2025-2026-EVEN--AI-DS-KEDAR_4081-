# %% [markdown]
# <a href="https://colab.research.google.com/github/chavakulakedar-lang/2025-2026-EVEN--AI-DS-KEDAR_4081-/blob/main/TUPLE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
t = (1, 2, 3)
print(t[0])
# Out:
# 1
