# %% [markdown]
# <a href="https://colab.research.google.com/github/chavakulakedar-lang/2025-2026-EVEN--AI-DS-KEDAR_4081-/blob/main/10_03_2026.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

data = [10, 20, 30, 40, 50]
mean = np.mean(data)
print("Mean:", mean)
std_dev = np.std(data, ddof=1)
print("Standard Deviation:", std_dev)
z_scores = [(value - mean) / std_dev for value in data]
print("Z-scores:", z_scores)
x = 40
z_score_40 = (x - mean) / std_dev
print("Z-score of 40:", z_score_40)
# Out:
# Mean: 30.0
# Standard Deviation: 15.811388300841896
# Z-scores: [np.float64(-1.2649110640673518), np.float64(-0.6324555320336759), np.float64(0.0), np.float64(0.6324555320336759), np.float64(1.2649110640673518)]
# Z-score of 40: 0.6324555320336759

# %%
import numpy as np
import math

population = np.array([10,20,30,40,50,60,70])
N = len(population)
print("population size (N):", N)
mu = np.mean(population)
print("population mean (μ):", mu)
sigma2 = np.var(population, ddof=0)
print("population variance (σ^2):", sigma2)
sigma = np.sqrt(sigma2)
print("population standard deviation:", sigma)
sample = np.array([20,30,40,50])
n = len(sample)
print("sample size (n):", n)
x_bar = np.mean(sample)
print("sample mean (x̄):", x_bar)
s2 = np.var(sample, ddof=1)
print("sample variance (s^2):", s2)
s = np.sqrt(s2)
print("sample standard deviation (s):", s)
SE = sigma / math.sqrt(n)
print("standard error (σ/√n):", SE)
z = (x_bar - mu) / SE
print("z-score:", z)
# Out:
# population size (N): 7
# population mean (μ): 40.0
# population variance (σ^2): 400.0
# population standard deviation: 20.0
# sample size (n): 4
# sample mean (x̄): 35.0
# sample variance (s^2): 166.66666666666666
# sample standard deviation (s): 12.909944487358056
# standard error (σ/√n): 10.0
# z-score: -0.5
